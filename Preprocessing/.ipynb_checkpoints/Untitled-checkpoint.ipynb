# %%
import librosa
import librosa.display
import librosa.feature
import librosa.util
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data_home = '/Volumes/MacPassport/IEMOCAP_full_release'

# %%
y, sr = librosa.load(audio_path)

# %%
D = np.abs(librosa.stft(y))

# %%
D.shape
# Out:
# (1025, 5755)

# %%
audio_df = pd.read_csv('/Volumes/MacPassport/IEMOCAP_full_release/preprocessing/df_iemocap.csv')
audio_df.head()
indexNames = audio_df[ audio_df['emotion'] == 'xxx' ].index
 
# Delete these row indexes from dataFrame
audio_df = audio_df.drop(indexNames , inplace=True)
audio_df.head(), len(audio_df)
# Out:
# (   start_time  end_time             wav_file emotion  val  act  dom
#  0      6.2901    8.2357  Ses01F_impro01_F000     neu  2.5  2.5  2.5
#  1     10.0100   11.3925  Ses01F_impro01_F001     neu  2.5  2.5  2.5
#  2     14.8872   18.0175  Ses01F_impro01_F002     neu  2.5  2.5  2.5
#  5     27.4600   31.4900  Ses01F_impro01_F005     neu  2.5  3.5  2.0
#  6     38.9650   43.5900  Ses01F_impro01_F006     fru  2.0  3.5  3.5, 7532)

# %%
start = np.array(audio_df['start_time'])
end = np.array(audio_df['end_time'])
durations = end - start
avg_duration = np.mean(durations)
avg_duration
# Out:
# 4.460108994919814

# %%
AUDIO_NUM = 1
filename = audio_df['wav_file'][AUDIO_NUM]
offset = audio_df['start_time'][AUDIO_NUM]
duration = float(audio_df['end_time'][AUDIO_NUM]) - float(audio_df['start_time'][AUDIO_NUM])
a1, sr1 = librosa.load(f'{data_home}/Session{filename[4]}/dialog/wav/{filename[:-5]}.wav',offset=offset,duration=avg_duration)


AUDIO_NUM = 19
filename = audio_df['wav_file'][AUDIO_NUM]
offset = audio_df['start_time'][AUDIO_NUM]
duration = float(audio_df['end_time'][AUDIO_NUM]) - float(audio_df['start_time'][AUDIO_NUM])
a2, sr2 = librosa.load(f'{data_home}/Session{filename[4]}/dialog/wav/{filename[:-5]}.wav',offset=offset,duration=avg_duration)

# %%
mel1 = np.abs((librosa.feature.melspectrogram(a1)))# mel1 = librosa.util.normalize(mel1)
mel2 = np.abs((librosa.feature.melspectrogram(a2)))
# mel2 = librosa.util.normalize(mel2)
librosa.power_to_db(mel1, ref=np.max)
# Out:
# array([[-29.892399, -28.029545, -29.105366, ..., -29.579145, -30.810663,
#         -32.216873],
#        [-31.65699 , -27.894978, -28.74274 , ..., -26.586487, -30.316513,
#         -30.059975],
#        [-32.647957, -32.610733, -32.06285 , ..., -35.139793, -31.878403,
#         -33.7589  ],
#        ...,
#        [-80.      , -80.      , -80.      , ..., -80.      , -80.      ,
#         -80.      ],
#        [-80.      , -80.      , -80.      , ..., -80.      , -80.      ,
#         -80.      ],
#        [-80.      , -80.      , -80.      , ..., -80.      , -80.      ,
#         -80.      ]], dtype=float32)

# %%
# plt.figure(figsize=(12, 4))
plt.subplot(2,1,1)

librosa.display.specshow(librosa.power_to_db(mel1, ref=np.max),
                         y_axis='mel', x_axis='time')
plt.subplot(2,1,2)
librosa.display.specshow(librosa.power_to_db(mel2, ref=np.max),
                         y_axis='mel', x_axis='time')
# librosa.display.specshow(mel1,x_axis='time',y_axis='linear',sr=sr)

# # librosa.display.specshow(mel2,x_axis='time',y_axis='mel',sr=sr)
# plt.show()

# %%
mel_spectrograms = np.zeros((7532,128,193))
mel_spectrograms_db = np.zeros((7532,128,193))
labels = {}
for i in range(len(audio_df)):
    filename = audio_df['wav_file'][AUDIO_NUM]
    offset = audio_df['start_time'][AUDIO_NUM]
    duration = float(audio_df['end_time'][AUDIO_NUM]) - float(audio_df['start_time'][AUDIO_NUM])
    a, sr = librosa.load(f'{data_home}/Session{filename[4]}/dialog/wav/{filename[:-5]}.wav',offset=offset,duration=avg_duration)
    mel1 = np.abs((librosa.feature.melspectrogram(a1)))
    mel_db = librosa.power_to_db(mel1, ref=np.max)
    spectrograms[i] = mel
    spectrograms_db[i] = mel_db

    if i%1000 == 0:
        print(f'{i}th vector complete')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-163-bf8fff4bf664> in <module>
#       5     offset = audio_df['start_time'][AUDIO_NUM]
#       6     duration = float(audio_df['end_time'][AUDIO_NUM]) - float(audio_df['start_time'][AUDIO_NUM])
# ----> 7     a, sr = librosa.load(f'{data_home}/Session{filename[4]}/dialog/wav/{filename[:-5]}.wav',offset=offset,duration=avg_duration)
#       8
#       9     mel1 = np.abs((librosa.feature.melspectrogram(a1)))
#
# /usr/local/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     147
#     148     if sr is not None:
# --> 149         y = resample(y, sr_native, sr, res_type=res_type)
#     150
#     151     else:
#
# /usr/local/lib/python3.7/site-packages/librosa/core/audio.py in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     517         y_hat = scipy.signal.resample_poly(y, target_sr // gcd, orig_sr // gcd, axis=-1)
#     518     else:
# --> 519         y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     520
#     521     if fix:
#
# /usr/local/lib/python3.7/site-packages/resampy/core.py in resample(x, sr_orig, sr_new, axis, filter, **kwargs)
#     118     x_2d = x.swapaxes(0, axis).reshape((x.shape[axis], -1))
#     119     y_2d = y.swapaxes(0, axis).reshape((y.shape[axis], -1))
# --> 120     resample_f(x_2d, y_2d, sample_ratio, interp_win, interp_delta, precision)
#     121
#     122     return y
#
# KeyboardInterrupt:

# %%
spectrograms
# Out:
# array([[[2.56655533e-02, 2.44708247e-02, 3.30815539e-02, ...,
#          3.57836336e-02, 6.40529394e-02, 5.28094210e-02],
#         [8.66263080e-03, 1.97956245e-02, 4.74296138e-02, ...,
#          3.88082042e-02, 1.01969607e-01, 1.13198698e-01],
#         [6.44882116e-03, 1.73159577e-02, 2.26639900e-02, ...,
#          2.26398613e-02, 2.88669728e-02, 1.96005721e-02],
#         ...,
#         [9.81622961e-08, 2.45404905e-08, 3.23739103e-17, ...,
#          2.46097969e-15, 3.40395729e-07, 1.75465334e-06],
#         [9.60225606e-08, 2.40055549e-08, 4.70103683e-17, ...,
#          2.55994511e-15, 3.32429778e-07, 1.71359011e-06],
#         [9.46764018e-08, 2.36690223e-08, 5.48568547e-17, ...,
#          2.64911058e-15, 3.27505290e-07, 1.68820554e-06]],
#
#        [[2.56655533e-02, 2.44708247e-02, 3.30815539e-02, ...,
#          3.57836336e-02, 6.40529394e-02, 5.28094210e-02],
#         [8.66263080e-03, 1.97956245e-02, 4.74296138e-02, ...,
#          3.88082042e-02, 1.01969607e-01, 1.13198698e-01],
#         [6.44882116e-03, 1.73159577e-02, 2.26639900e-02, ...,
#          2.26398613e-02, 2.88669728e-02, 1.96005721e-02],
#         ...,
#         [9.81622961e-08, 2.45404905e-08, 3.23739103e-17, ...,
#          2.46097969e-15, 3.40395729e-07, 1.75465334e-06],
#         [9.60225606e-08, 2.40055549e-08, 4.70103683e-17, ...,
#          2.55994511e-15, 3.32429778e-07, 1.71359011e-06],
#         [9.46764018e-08, 2.36690223e-08, 5.48568547e-17, ...,
#          2.64911058e-15, 3.27505290e-07, 1.68820554e-06]],
#
#        [[2.56655533e-02, 2.44708247e-02, 3.30815539e-02, ...,
#          3.57836336e-02, 6.40529394e-02, 5.28094210e-02],
#         [8.66263080e-03, 1.97956245e-02, 4.74296138e-02, ...,
#          3.88082042e-02, 1.01969607e-01, 1.13198698e-01],
#         [6.44882116e-03, 1.73159577e-02, 2.26639900e-02, ...,
#          2.26398613e-02, 2.88669728e-02, 1.96005721e-02],
#         ...,
#         [9.81622961e-08, 2.45404905e-08, 3.23739103e-17, ...,
#          2.46097969e-15, 3.40395729e-07, 1.75465334e-06],
#         [9.60225606e-08, 2.40055549e-08, 4.70103683e-17, ...,
#          2.55994511e-15, 3.32429778e-07, 1.71359011e-06],
#         [9.46764018e-08, 2.36690223e-08, 5.48568547e-17, ...,
#          2.64911058e-15, 3.27505290e-07, 1.68820554e-06]],
#
#        ...,
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#        [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         ...,
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#          0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]])

# %%
spectrograms_mini = spectrograms[:9270]

# %%
normalized_spectrograms = librosa.util.normalize(spectrograms_mini)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-3774aaf49896> in <module>
# ----> 1 normalized_spectrograms = librosa.util.normalize(spectrograms_mini)
#
# /usr/local/lib/python3.7/site-packages/librosa/util/utils.py in normalize(S, norm, axis, threshold, fill)
#     720         raise ParameterError('fill={} must be None or boolean'.format(fill))
#     721
# --> 722     if not np.all(np.isfinite(S)):
#     723         raise ParameterError('Input must be finite')
#     724
#
# KeyboardInterrupt:

# %%
audio_df['emotion'][0] != 'neu'
# Out:
# False
